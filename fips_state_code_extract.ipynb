# %%
import pymongo
import pandas as pd

# %%
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)

# db = client.

# %%
url = 'https://www.census.gov/library/reference/code-lists/ansi.html'

# %%
tables = pd.read_html(url)
# len(tables)
df = tables[6]
df
# Out:
#                     Name  FIPS State Numeric Code Official USPS Code
# 0                Alabama                        1                 AL
# 1                 Alaska                        2                 AK
# 2                Arizona                        4                 AZ
# 3               Arkansas                        5                 AR
# 4             California                        6                 CA
# 5               Colorado                        8                 CO
# 6            Connecticut                        9                 CT
# 7               Delaware                       10                 DE
# 8   District of Columbia                       11                 DC
# 9                Florida                       12                 FL
# 10               Georgia                       13                 GA
# 11                Hawaii                       15                 HI
# 12                 Idaho                       16                 ID
# ...

# %%
df['FIPS State Numeric Code'].dtype
# Out:
# dtype('int64')

# %%
df['FIPS State Numeric Code']= df['FIPS State Numeric Code'].values.astype(str)
df['FIPS State Numeric Code'].dtype
# Out:
# dtype('O')

# %%
df['FIPS State Numeric Code'] = df['FIPS State Numeric Code'].str.zfill(2)

# %%
df
# Out:
#                     Name FIPS State Numeric Code Official USPS Code
# 0                Alabama                      01                 AL
# 1                 Alaska                      02                 AK
# 2                Arizona                      04                 AZ
# 3               Arkansas                      05                 AR
# 4             California                      06                 CA
# 5               Colorado                      08                 CO
# 6            Connecticut                      09                 CT
# 7               Delaware                      10                 DE
# 8   District of Columbia                      11                 DC
# 9                Florida                      12                 FL
# 10               Georgia                      13                 GA
# 11                Hawaii                      15                 HI
# 12                 Idaho                      16                 ID
# ...

# %%
df.to_csv('../Resources/fips_state_codes.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-68-d2e2e88c7b22> in <module>
# ----> 1 df.to_csv('../Resources/fips_state_codes.csv')
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
# ...

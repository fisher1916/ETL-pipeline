# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
from us import states

# Census API key
from Zip_census import court_api_key
c = Census(court_api_key, year=2018)

# %% [markdown]
# # Import Data

# %%
#Import Data
#from https://simplemaps.com/data/us-zips

dataMain = pd.read_csv("Resources/uszips.csv")
dataMain
# Out:
#          zip       lat        lng         city state_id   state_name  zcta  \
# 0        601  18.18004  -66.75218     Adjuntas       PR  Puerto Rico  True
# 1        602  18.36073  -67.17517       Aguada       PR  Puerto Rico  True
# 2        603  18.45439  -67.12202    Aguadilla       PR  Puerto Rico  True
# 3        606  18.16724  -66.93828      Maricao       PR  Puerto Rico  True
# 4        610  18.29032  -67.12243       Anasco       PR  Puerto Rico  True
# ...      ...       ...        ...          ...      ...          ...   ...
# 33092  99923  55.97796 -130.03671        Hyder       AK       Alaska  True
# 33093  99925  55.55767 -132.97627      Klawock       AK       Alaska  True
# 33094  99926  55.12617 -131.48928   Metlakatla       AK       Alaska  True
# 33095  99927  56.25100 -133.37571  Point Baker       AK       Alaska  True
# 33096  99929  56.36950 -131.93648     Wrangell       AK       Alaska  True
#
# ...

# %% [markdown]
# # Clean Data

# %%
#Convert data to dataframe, perform some basic operations
#Keep zip, lat, lng, city, state_name, county_fips, county_name, county_fips_all
#drop the rest

data_df = pd.DataFrame(dataMain)

data_df.drop(columns=['state_id','zcta','parent_zcta', 'density', 'county_weights', 'county_names_all', 'imprecise', 'military', 'timezone', 'county_fips_all'],inplace=True)
data_df.dropna(how="any", inplace=True)

data_df
# Out:
#          zip       lat        lng         city   state_name  population  \
# 0        601  18.18004  -66.75218     Adjuntas  Puerto Rico       17242
# 1        602  18.36073  -67.17517       Aguada  Puerto Rico       38442
# 2        603  18.45439  -67.12202    Aguadilla  Puerto Rico       48814
# 3        606  18.16724  -66.93828      Maricao  Puerto Rico        6437
# 4        610  18.29032  -67.12243       Anasco  Puerto Rico       27073
# ...      ...       ...        ...          ...          ...         ...
# 33092  99923  55.97796 -130.03671        Hyder       Alaska          15
# 33093  99925  55.55767 -132.97627      Klawock       Alaska         927
# 33094  99926  55.12617 -131.48928   Metlakatla       Alaska        1635
# 33095  99927  56.25100 -133.37571  Point Baker       Alaska          38
# 33096  99929  56.36950 -131.93648     Wrangell       Alaska        2484
#
#        county_fips            county_name
# 0            72001               Adjuntas
# ...

# %% [markdown]
# # Save as CSV

# %%
#Save as a csv
#Using encoding="utf-8" to avoid issues later
data_df.to_csv("zip_Lat_Lon_task.csv", encoding="utf-8", index=False)

# %%
import pandas as pd 

# The path to our CSV file
file = "Resources/cms_data_2.csv"

# Read our data into pandas
df = pd.read_csv(file)
df.head() 

# Get a list of all of our columns for easy reference
df.columns
# Out:
# Index(['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Measure ID', 'Measure Name',
#        'Compared to National', 'Denominator', 'Score', 'Lower Estimate',
#        'Higher Estimate', 'Footnote', 'Start Date', 'End Date'],
#       dtype='object')

# %%
# Extract 'Facility ID', 'Facility Name', 'Address City','State', 'ZIP Code', 'County Name',
CMS_df = df.loc[:, ['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
       'County Name', 'Measure ID', 'Measure Name',
       'Denominator', 'Score', 'Lower Estimate',
       'Higher Estimate','Start Date', 'End Date']]
CMS_df
# Out:
#       Facility ID                              Facility Name  \
# 0           10001           SOUTHEAST ALABAMA MEDICAL CENTER
# 1          360180                           CLEVELAND CLINIC
# 2          210063  UNIVERSITY OF MD ST JOSEPH MEDICAL CENTER
# 3          330101             NEW YORK-PRESBYTERIAN HOSPITAL
# 4           90011         MEDSTAR WASHINGTON HOSPITAL CENTER
# ...           ...                                        ...
# 91033      670132               METHODIST SOUTHLAKE HOSPITAL
# 91034      670132               METHODIST SOUTHLAKE HOSPITAL
# 91035      670132               METHODIST SOUTHLAKE HOSPITAL
# 91036      670132               METHODIST SOUTHLAKE HOSPITAL
# 91037      670132               METHODIST SOUTHLAKE HOSPITAL
#
#                        Address        City State  ZIP Code   County Name  \
# 0       1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301       HOUSTON
# 1           9500 EUCLID AVENUE   CLEVELAND    OH     44195      CUYAHOGA
# 2             7601 OSLER DRIVE      TOWSON    MD     21204     BALTIMORE
# 3         525 EAST 68TH STREET    NEW YORK    NY     10065      NEW YORK
# 4         110 IRVING STREET NW  WASHINGTON    DC     20010  THE DISTRICT
# ...                        ...         ...   ...       ...           ...
# 91033  421 E STATE HIGHWAY 114   SOUTHLAKE    TX     76092       TARRANT
# 91034  421 E STATE HIGHWAY 114   SOUTHLAKE    TX     76092       TARRANT
# 91035  421 E STATE HIGHWAY 114   SOUTHLAKE    TX     76092       TARRANT
# 91036  421 E STATE HIGHWAY 114   SOUTHLAKE    TX     76092       TARRANT
# 91037  421 E STATE HIGHWAY 114   SOUTHLAKE    TX     76092       TARRANT
#
#             Measure ID                                       Measure Name  \
# 0        COMP_HIP_KNEE  Rate of complications for hip/knee replacement...
# 1         MORT_30_CABG               Death rate for CABG surgery patients
# 2         MORT_30_CABG               Death rate for CABG surgery patients
# 3         MORT_30_CABG               Death rate for CABG surgery patients
# 4         MORT_30_CABG               Death rate for CABG surgery patients
# ...                ...                                                ...
# 91033  PSI_4_SURG_COMP  Deaths among Patients with Serious Treatable C...
# 91034    PSI_6_IAT_PTX            Collapsed lung due to medical treatment
# 91035   PSI_8_POST_HIP               Broken hip from a fall after surgery
# 91036    PSI_90_SAFETY                              Serious complications
# 91037   PSI_9_POST_HEM          Perioperative Hemorrhage or Hematoma Rate
#
#           Denominator          Score Lower Estimate Higher Estimate  \
# 0                 250            2.3            1.4             3.7
# 1                 408            1.4            0.7             2.6
# 2                 380            1.5            0.8             2.7
# 3                 563            1.5            0.9             2.5
# 4                 852            1.6            1.1             2.4
# ...               ...            ...            ...             ...
# 91033   Not Available  Not Available  Not Available   Not Available
# 91034   Not Available  Not Available  Not Available   Not Available
# 91035   Not Available  Not Available  Not Available   Not Available
# 91036  Not Applicable  Not Available  Not Available   Not Available
# 91037   Not Available  Not Available  Not Available   Not Available
#
#       Start Date   End Date
# 0       4/1/2016  3/31/2019
# 1       7/1/2016  6/30/2019
# 2       7/1/2016  6/30/2019
# 3       7/1/2016  6/30/2019
# 4       7/1/2016  6/30/2019
# ...          ...        ...
# 91033   7/1/2017  6/30/2019
# 91034   7/1/2017  6/30/2019
# 91035   7/1/2017  6/30/2019
# 91036   7/1/2017  6/30/2019
# 91037   7/1/2017  6/30/2019
#
# [91038 rows x 15 columns]

# %%
#checking for null values
CMS_df.isnull().values.any()
# Out:
# False

# %%
#find hospitals with not available or in score column
cms_df_na_drop = CMS_df.loc[CMS_df["Score"] == "Not Available"]
cms_df_na_drop
# Out:
#       Facility ID                 Facility Name                  Address  \
# 57          10007      MIZELL MEMORIAL HOSPITAL            702 N MAIN ST
# 71          10007      MIZELL MEMORIAL HOSPITAL            702 N MAIN ST
# 76          10008   CRENSHAW COMMUNITY HOSPITAL      101 HOSPITAL CIRCLE
# 83          10008   CRENSHAW COMMUNITY HOSPITAL      101 HOSPITAL CIRCLE
# 84          10008   CRENSHAW COMMUNITY HOSPITAL      101 HOSPITAL CIRCLE
# ...           ...                           ...                      ...
# 91033      670132  METHODIST SOUTHLAKE HOSPITAL  421 E STATE HIGHWAY 114
# 91034      670132  METHODIST SOUTHLAKE HOSPITAL  421 E STATE HIGHWAY 114
# 91035      670132  METHODIST SOUTHLAKE HOSPITAL  421 E STATE HIGHWAY 114
# 91036      670132  METHODIST SOUTHLAKE HOSPITAL  421 E STATE HIGHWAY 114
# 91037      670132  METHODIST SOUTHLAKE HOSPITAL  421 E STATE HIGHWAY 114
#
#             City State  ZIP Code County Name          Measure ID  \
# 57           OPP    AL     36467   COVINGTON       COMP_HIP_KNEE
# 71           OPP    AL     36467   COVINGTON     PSI_4_SURG_COMP
# 76       LUVERNE    AL     36049    CRENSHAW       COMP_HIP_KNEE
# 83       LUVERNE    AL     36049    CRENSHAW  PSI_10_POST_KIDNEY
# 84       LUVERNE    AL     36049    CRENSHAW    PSI_11_POST_RESP
# ...          ...   ...       ...         ...                 ...
# 91033  SOUTHLAKE    TX     76092     TARRANT     PSI_4_SURG_COMP
# 91034  SOUTHLAKE    TX     76092     TARRANT       PSI_6_IAT_PTX
# 91035  SOUTHLAKE    TX     76092     TARRANT      PSI_8_POST_HIP
# 91036  SOUTHLAKE    TX     76092     TARRANT       PSI_90_SAFETY
# 91037  SOUTHLAKE    TX     76092     TARRANT      PSI_9_POST_HEM
#
#                                             Measure Name     Denominator  \
# 57     Rate of complications for hip/knee replacement...   Not Available
# 71     Deaths among Patients with Serious Treatable C...   Not Available
# 76     Rate of complications for hip/knee replacement...   Not Available
# 83     Postoperative Acute Kidney Injury Requiring Di...   Not Available
# 84                Postoperative Respiratory Failure Rate   Not Available
# ...                                                  ...             ...
# 91033  Deaths among Patients with Serious Treatable C...   Not Available
# 91034            Collapsed lung due to medical treatment   Not Available
# 91035               Broken hip from a fall after surgery   Not Available
# 91036                              Serious complications  Not Applicable
# 91037          Perioperative Hemorrhage or Hematoma Rate   Not Available
#
#                Score Lower Estimate Higher Estimate Start Date   End Date
# 57     Not Available  Not Available   Not Available   4/1/2016  3/31/2019
# 71     Not Available  Not Available   Not Available   7/1/2017  6/30/2019
# 76     Not Available  Not Available   Not Available   4/1/2016  3/31/2019
# 83     Not Available  Not Available   Not Available   7/1/2017  6/30/2019
# 84     Not Available  Not Available   Not Available   7/1/2017  6/30/2019
# ...              ...            ...             ...        ...        ...
# 91033  Not Available  Not Available   Not Available   7/1/2017  6/30/2019
# 91034  Not Available  Not Available   Not Available   7/1/2017  6/30/2019
# 91035  Not Available  Not Available   Not Available   7/1/2017  6/30/2019
# 91036  Not Available  Not Available   Not Available   7/1/2017  6/30/2019
# 91037  Not Available  Not Available   Not Available   7/1/2017  6/30/2019
#
# [37574 rows x 15 columns]

# %%
#filter out hospitals with not available in score column
cms_df_na = CMS_df[CMS_df["Score"] != "Not Available"]
cms_df_na
# Out:
#       Facility ID                                     Facility Name  \
# 0           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          360180                                  CLEVELAND CLINIC
# 2          210063         UNIVERSITY OF MD ST JOSEPH MEDICAL CENTER
# 3          330101                    NEW YORK-PRESBYTERIAN HOSPITAL
# 4           90011                MEDSTAR WASHINGTON HOSPITAL CENTER
# ...           ...                                               ...
# 90922      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 90956      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 90958      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 90959      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 90960      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 0                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 1                    9500 EUCLID AVENUE     CLEVELAND    OH     44195
# 2                      7601 OSLER DRIVE        TOWSON    MD     21204
# 3                  525 EAST 68TH STREET      NEW YORK    NY     10065
# 4                  110 IRVING STREET NW    WASHINGTON    DC     20010
# ...                                 ...           ...   ...       ...
# 90922   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 90956  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 90958  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 90959  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 90960  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#         County Name      Measure ID  \
# 0           HOUSTON   COMP_HIP_KNEE
# 1          CUYAHOGA    MORT_30_CABG
# 2         BALTIMORE    MORT_30_CABG
# 3          NEW YORK    MORT_30_CABG
# 4      THE DISTRICT    MORT_30_CABG
# ...             ...             ...
# 90922       EL PASO   PSI_90_SAFETY
# 90956        TRAVIS     PSI_3_ULCER
# 90958        TRAVIS   PSI_6_IAT_PTX
# 90959        TRAVIS  PSI_8_POST_HIP
# 90960        TRAVIS   PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 0      Rate of complications for hip/knee replacement...             250
# 1                   Death rate for CABG surgery patients             408
# 2                   Death rate for CABG surgery patients             380
# 3                   Death rate for CABG surgery patients             563
# 4                   Death rate for CABG surgery patients             852
# ...                                                  ...             ...
# 90922                              Serious complications  Not Applicable
# 90956                                     Pressure sores              32
# 90958            Collapsed lung due to medical treatment              59
# 90959               Broken hip from a fall after surgery              55
# 90960                              Serious complications  Not Applicable
#
#       Score Lower Estimate Higher Estimate Start Date   End Date
# 0       2.3            1.4             3.7   4/1/2016  3/31/2019
# 1       1.4            0.7             2.6   7/1/2016  6/30/2019
# 2       1.5            0.8             2.7   7/1/2016  6/30/2019
# 3       1.5            0.9             2.5   7/1/2016  6/30/2019
# 4       1.6            1.1             2.4   7/1/2016  6/30/2019
# ...     ...            ...             ...        ...        ...
# 90922     1            0.5            1.49   7/1/2017  6/30/2019
# 90956  0.59              0               2   7/1/2017  6/30/2019
# 90958  0.25           0.03            0.48   7/1/2017  6/30/2019
# 90959  0.11           0.04            0.18   7/1/2017  6/30/2019
# 90960  0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [53464 rows x 15 columns]

# %%
#reset index
cms_df_reset = cms_df_na.reset_index(drop=True)
cms_df_reset
# Out:
#       Facility ID                                     Facility Name  \
# 0           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 1          360180                                  CLEVELAND CLINIC
# 2          210063         UNIVERSITY OF MD ST JOSEPH MEDICAL CENTER
# 3          330101                    NEW YORK-PRESBYTERIAN HOSPITAL
# 4           90011                MEDSTAR WASHINGTON HOSPITAL CENTER
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 0                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 1                    9500 EUCLID AVENUE     CLEVELAND    OH     44195
# 2                      7601 OSLER DRIVE        TOWSON    MD     21204
# 3                  525 EAST 68TH STREET      NEW YORK    NY     10065
# 4                  110 IRVING STREET NW    WASHINGTON    DC     20010
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#         County Name      Measure ID  \
# 0           HOUSTON   COMP_HIP_KNEE
# 1          CUYAHOGA    MORT_30_CABG
# 2         BALTIMORE    MORT_30_CABG
# 3          NEW YORK    MORT_30_CABG
# 4      THE DISTRICT    MORT_30_CABG
# ...             ...             ...
# 53459       EL PASO   PSI_90_SAFETY
# 53460        TRAVIS     PSI_3_ULCER
# 53461        TRAVIS   PSI_6_IAT_PTX
# 53462        TRAVIS  PSI_8_POST_HIP
# 53463        TRAVIS   PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 0      Rate of complications for hip/knee replacement...             250
# 1                   Death rate for CABG surgery patients             408
# 2                   Death rate for CABG surgery patients             380
# 3                   Death rate for CABG surgery patients             563
# 4                   Death rate for CABG surgery patients             852
# ...                                                  ...             ...
# 53459                              Serious complications  Not Applicable
# 53460                                     Pressure sores              32
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#       Score Lower Estimate Higher Estimate Start Date   End Date
# 0       2.3            1.4             3.7   4/1/2016  3/31/2019
# 1       1.4            0.7             2.6   7/1/2016  6/30/2019
# 2       1.5            0.8             2.7   7/1/2016  6/30/2019
# 3       1.5            0.9             2.5   7/1/2016  6/30/2019
# 4       1.6            1.1             2.4   7/1/2016  6/30/2019
# ...     ...            ...             ...        ...        ...
# 53459     1            0.5            1.49   7/1/2017  6/30/2019
# 53460  0.59              0               2   7/1/2017  6/30/2019
# 53461  0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462  0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463  0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [53464 rows x 15 columns]

# %%
#filter out COMP_HIP_KNEE measure
cms_df_m = cms_df_reset[cms_df_reset["Measure ID"] != "COMP_HIP_KNEE"]
cms_df_m
# Out:
#       Facility ID                                     Facility Name  \
# 1          360180                                  CLEVELAND CLINIC
# 2          210063         UNIVERSITY OF MD ST JOSEPH MEDICAL CENTER
# 3          330101                    NEW YORK-PRESBYTERIAN HOSPITAL
# 4           90011                MEDSTAR WASHINGTON HOSPITAL CENTER
# 5          150153            ST VINCENT HEART CENTER OF INDIANA LLC
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 1                    9500 EUCLID AVENUE     CLEVELAND    OH     44195
# 2                      7601 OSLER DRIVE        TOWSON    MD     21204
# 3                  525 EAST 68TH STREET      NEW YORK    NY     10065
# 4                  110 IRVING STREET NW    WASHINGTON    DC     20010
# 5                   10580 N MERIDIAN ST  INDIANAPOLIS    IN     46290
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#         County Name      Measure ID                             Measure Name  \
# 1          CUYAHOGA    MORT_30_CABG     Death rate for CABG surgery patients
# 2         BALTIMORE    MORT_30_CABG     Death rate for CABG surgery patients
# 3          NEW YORK    MORT_30_CABG     Death rate for CABG surgery patients
# 4      THE DISTRICT    MORT_30_CABG     Death rate for CABG surgery patients
# 5          HAMILTON    MORT_30_CABG     Death rate for CABG surgery patients
# ...             ...             ...                                      ...
# 53459       EL PASO   PSI_90_SAFETY                    Serious complications
# 53460        TRAVIS     PSI_3_ULCER                           Pressure sores
# 53461        TRAVIS   PSI_6_IAT_PTX  Collapsed lung due to medical treatment
# 53462        TRAVIS  PSI_8_POST_HIP     Broken hip from a fall after surgery
# 53463        TRAVIS   PSI_90_SAFETY                    Serious complications
#
#           Denominator Score Lower Estimate Higher Estimate Start Date  \
# 1                 408   1.4            0.7             2.6   7/1/2016
# 2                 380   1.5            0.8             2.7   7/1/2016
# 3                 563   1.5            0.9             2.5   7/1/2016
# 4                 852   1.6            1.1             2.4   7/1/2016
# 5                 424   1.6            0.9             2.9   7/1/2016
# ...               ...   ...            ...             ...        ...
# 53459  Not Applicable     1            0.5            1.49   7/1/2017
# 53460              32  0.59              0               2   7/1/2017
# 53461              59  0.25           0.03            0.48   7/1/2017
# 53462              55  0.11           0.04            0.18   7/1/2017
# 53463  Not Applicable  0.99            0.5            1.49   7/1/2017
#
#         End Date
# 1      6/30/2019
# 2      6/30/2019
# 3      6/30/2019
# 4      6/30/2019
# 5      6/30/2019
# ...          ...
# 53459  6/30/2019
# 53460  6/30/2019
# 53461  6/30/2019
# 53462  6/30/2019
# 53463  6/30/2019
#
# [50763 rows x 15 columns]

# %%
#filter out MORT_30_CABG measure

cms_df_n = cms_df_m[cms_df_m["Measure ID"] != "MORT_30_CABG"]
cms_df_n
# Out:
#       Facility ID                                     Facility Name  \
# 7           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 8           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 9           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 10          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 11          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 7                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 8                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 9                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 10               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 11               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name                 Measure ID  \
# 7         HOUSTON         PSI_10_POST_KIDNEY
# 8         HOUSTON           PSI_11_POST_RESP
# 9         HOUSTON  PSI_12_POSTOP_PULMEMB_DVT
# 10        HOUSTON         PSI_13_POST_SEPSIS
# 11        HOUSTON        PSI_14_POSTOP_DEHIS
# ...           ...                        ...
# 53459     EL PASO              PSI_90_SAFETY
# 53460      TRAVIS                PSI_3_ULCER
# 53461      TRAVIS              PSI_6_IAT_PTX
# 53462      TRAVIS             PSI_8_POST_HIP
# 53463      TRAVIS              PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 7      Postoperative Acute Kidney Injury Requiring Di...            1507
# 8                 Postoperative Respiratory Failure Rate            1045
# 9                      Serious blood clots after surgery            3753
# 10                  Blood stream infection after surgery            1423
# 11     A wound that splits open after surgery on the ...             870
# ...                                                  ...             ...
# 53459                              Serious complications  Not Applicable
# 53460                                     Pressure sores              32
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#       Score Lower Estimate Higher Estimate Start Date   End Date
# 7      0.82              0            1.85   7/1/2017  6/30/2019
# 8      7.93           4.06           11.81   7/1/2017  6/30/2019
# 9      2.64              1            4.29   7/1/2017  6/30/2019
# 10     4.65           2.23            7.07   7/1/2017  6/30/2019
# 11     0.83           0.16            1.49   7/1/2017  6/30/2019
# ...     ...            ...             ...        ...        ...
# 53459     1            0.5            1.49   7/1/2017  6/30/2019
# 53460  0.59              0               2   7/1/2017  6/30/2019
# 53461  0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462  0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463  0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [49774 rows x 15 columns]

# %%
#filter out PSI_10_POST_KIDNEY measure
cms_df_p = cms_df_n[cms_df_n["Measure ID"] != "PSI_10_POST_KIDNEY"]
cms_df_p
# Out:
#       Facility ID                                     Facility Name  \
# 8           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 9           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 10          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 11          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 12          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 8                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 9                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 10               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 11               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 12               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name                 Measure ID  \
# 8         HOUSTON           PSI_11_POST_RESP
# 9         HOUSTON  PSI_12_POSTOP_PULMEMB_DVT
# 10        HOUSTON         PSI_13_POST_SEPSIS
# 11        HOUSTON        PSI_14_POSTOP_DEHIS
# 12        HOUSTON             PSI_15_ACC_LAC
# ...           ...                        ...
# 53459     EL PASO              PSI_90_SAFETY
# 53460      TRAVIS                PSI_3_ULCER
# 53461      TRAVIS              PSI_6_IAT_PTX
# 53462      TRAVIS             PSI_8_POST_HIP
# 53463      TRAVIS              PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 8                 Postoperative Respiratory Failure Rate            1045
# 9                      Serious blood clots after surgery            3753
# 10                  Blood stream infection after surgery            1423
# 11     A wound that splits open after surgery on the ...             870
# 12      Accidental cuts and tears from medical treatment            2401
# ...                                                  ...             ...
# 53459                              Serious complications  Not Applicable
# 53460                                     Pressure sores              32
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#       Score Lower Estimate Higher Estimate Start Date   End Date
# 8      7.93           4.06           11.81   7/1/2017  6/30/2019
# 9      2.64              1            4.29   7/1/2017  6/30/2019
# 10     4.65           2.23            7.07   7/1/2017  6/30/2019
# 11     0.83           0.16            1.49   7/1/2017  6/30/2019
# 12     0.96              0            1.95   7/1/2017  6/30/2019
# ...     ...            ...             ...        ...        ...
# 53459     1            0.5            1.49   7/1/2017  6/30/2019
# 53460  0.59              0               2   7/1/2017  6/30/2019
# 53461  0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462  0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463  0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [47047 rows x 15 columns]

# %%
#filter out PSI_11_POST_RESP measure
cms_df_r = cms_df_p[cms_df_p["Measure ID"] != "PSI_11_POST_RESP"]
cms_df_r
# Out:
#       Facility ID                                     Facility Name  \
# 9           10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 10          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 11          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 12          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 13          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 9                1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 10               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 11               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 12               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 13               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name                 Measure ID  \
# 9         HOUSTON  PSI_12_POSTOP_PULMEMB_DVT
# 10        HOUSTON         PSI_13_POST_SEPSIS
# 11        HOUSTON        PSI_14_POSTOP_DEHIS
# 12        HOUSTON             PSI_15_ACC_LAC
# 13        HOUSTON                PSI_3_ULCER
# ...           ...                        ...
# 53459     EL PASO              PSI_90_SAFETY
# 53460      TRAVIS                PSI_3_ULCER
# 53461      TRAVIS              PSI_6_IAT_PTX
# 53462      TRAVIS             PSI_8_POST_HIP
# 53463      TRAVIS              PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 9                      Serious blood clots after surgery            3753
# 10                  Blood stream infection after surgery            1423
# 11     A wound that splits open after surgery on the ...             870
# 12      Accidental cuts and tears from medical treatment            2401
# 13                                        Pressure sores            9998
# ...                                                  ...             ...
# 53459                              Serious complications  Not Applicable
# 53460                                     Pressure sores              32
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#       Score Lower Estimate Higher Estimate Start Date   End Date
# 9      2.64              1            4.29   7/1/2017  6/30/2019
# 10     4.65           2.23            7.07   7/1/2017  6/30/2019
# 11     0.83           0.16            1.49   7/1/2017  6/30/2019
# 12     0.96              0            1.95   7/1/2017  6/30/2019
# 13     0.58           0.13            1.03   7/1/2017  6/30/2019
# ...     ...            ...             ...        ...        ...
# 53459     1            0.5            1.49   7/1/2017  6/30/2019
# 53460  0.59              0               2   7/1/2017  6/30/2019
# 53461  0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462  0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463  0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [44349 rows x 15 columns]

# %%
#filter out PSI_12_POSTOP_PULMEMB_DVT measure
cms_df_s = cms_df_r[cms_df_r["Measure ID"] != "PSI_12_POSTOP_PULMEMB_DVT"]
cms_df_s
# Out:
#       Facility ID                                     Facility Name  \
# 10          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 11          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 12          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 13          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 14          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 10               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 11               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 12               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 13               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 14               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name           Measure ID  \
# 10        HOUSTON   PSI_13_POST_SEPSIS
# 11        HOUSTON  PSI_14_POSTOP_DEHIS
# 12        HOUSTON       PSI_15_ACC_LAC
# 13        HOUSTON          PSI_3_ULCER
# 14        HOUSTON      PSI_4_SURG_COMP
# ...           ...                  ...
# 53459     EL PASO        PSI_90_SAFETY
# 53460      TRAVIS          PSI_3_ULCER
# 53461      TRAVIS        PSI_6_IAT_PTX
# 53462      TRAVIS       PSI_8_POST_HIP
# 53463      TRAVIS        PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 10                  Blood stream infection after surgery            1423
# 11     A wound that splits open after surgery on the ...             870
# 12      Accidental cuts and tears from medical treatment            2401
# 13                                        Pressure sores            9998
# 14     Deaths among Patients with Serious Treatable C...             165
# ...                                                  ...             ...
# 53459                              Serious complications  Not Applicable
# 53460                                     Pressure sores              32
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#         Score Lower Estimate Higher Estimate Start Date   End Date
# 10       4.65           2.23            7.07   7/1/2017  6/30/2019
# 11       0.83           0.16            1.49   7/1/2017  6/30/2019
# 12       0.96              0            1.95   7/1/2017  6/30/2019
# 13       0.58           0.13            1.03   7/1/2017  6/30/2019
# 14     170.87         134.19          207.56   7/1/2017  6/30/2019
# ...       ...            ...             ...        ...        ...
# 53459       1            0.5            1.49   7/1/2017  6/30/2019
# 53460    0.59              0               2   7/1/2017  6/30/2019
# 53461    0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462    0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463    0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [41425 rows x 15 columns]

# %%
#filter out PSI_13_POST_SEPSIS measure
cms_df_t = cms_df_s[cms_df_s["Measure ID"] != "PSI_13_POST_SEPSIS"]
cms_df_t
# Out:
#       Facility ID                                     Facility Name  \
# 11          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 12          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 13          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 14          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 15          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 11               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 12               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 13               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 14               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 15               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name           Measure ID  \
# 11        HOUSTON  PSI_14_POSTOP_DEHIS
# 12        HOUSTON       PSI_15_ACC_LAC
# 13        HOUSTON          PSI_3_ULCER
# 14        HOUSTON      PSI_4_SURG_COMP
# 15        HOUSTON        PSI_6_IAT_PTX
# ...           ...                  ...
# 53459     EL PASO        PSI_90_SAFETY
# 53460      TRAVIS          PSI_3_ULCER
# 53461      TRAVIS        PSI_6_IAT_PTX
# 53462      TRAVIS       PSI_8_POST_HIP
# 53463      TRAVIS        PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 11     A wound that splits open after surgery on the ...             870
# 12      Accidental cuts and tears from medical treatment            2401
# 13                                        Pressure sores            9998
# 14     Deaths among Patients with Serious Treatable C...             165
# 15               Collapsed lung due to medical treatment           12963
# ...                                                  ...             ...
# 53459                              Serious complications  Not Applicable
# 53460                                     Pressure sores              32
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#         Score Lower Estimate Higher Estimate Start Date   End Date
# 11       0.83           0.16            1.49   7/1/2017  6/30/2019
# 12       0.96              0            1.95   7/1/2017  6/30/2019
# 13       0.58           0.13            1.03   7/1/2017  6/30/2019
# 14     170.87         134.19          207.56   7/1/2017  6/30/2019
# 15       0.23           0.06            0.39   7/1/2017  6/30/2019
# ...       ...            ...             ...        ...        ...
# 53459       1            0.5            1.49   7/1/2017  6/30/2019
# 53460    0.59              0               2   7/1/2017  6/30/2019
# 53461    0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462    0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463    0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [38722 rows x 15 columns]

# %%
#filter out PSI_14_POSTOP_DEHIS measure
cms_df_v = cms_df_t[cms_df_t["Measure ID"] != "PSI_14_POSTOP_DEHIS"]
cms_df_v
# Out:
#       Facility ID                                     Facility Name  \
# 12          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 13          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 14          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 15          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 16          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 12               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 13               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 14               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 15               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 16               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name       Measure ID  \
# 12        HOUSTON   PSI_15_ACC_LAC
# 13        HOUSTON      PSI_3_ULCER
# 14        HOUSTON  PSI_4_SURG_COMP
# 15        HOUSTON    PSI_6_IAT_PTX
# 16        HOUSTON   PSI_8_POST_HIP
# ...           ...              ...
# 53459     EL PASO    PSI_90_SAFETY
# 53460      TRAVIS      PSI_3_ULCER
# 53461      TRAVIS    PSI_6_IAT_PTX
# 53462      TRAVIS   PSI_8_POST_HIP
# 53463      TRAVIS    PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 12      Accidental cuts and tears from medical treatment            2401
# 13                                        Pressure sores            9998
# 14     Deaths among Patients with Serious Treatable C...             165
# 15               Collapsed lung due to medical treatment           12963
# 16                  Broken hip from a fall after surgery           10786
# ...                                                  ...             ...
# 53459                              Serious complications  Not Applicable
# 53460                                     Pressure sores              32
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#         Score Lower Estimate Higher Estimate Start Date   End Date
# 12       0.96              0            1.95   7/1/2017  6/30/2019
# 13       0.58           0.13            1.03   7/1/2017  6/30/2019
# 14     170.87         134.19          207.56   7/1/2017  6/30/2019
# 15       0.23           0.06            0.39   7/1/2017  6/30/2019
# 16        0.1           0.03            0.17   7/1/2017  6/30/2019
# ...       ...            ...             ...        ...        ...
# 53459       1            0.5            1.49   7/1/2017  6/30/2019
# 53460    0.59              0               2   7/1/2017  6/30/2019
# 53461    0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462    0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463    0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [36040 rows x 15 columns]

# %%
#filter out PSI_15_ACC_LAC measure
cms_df_w = cms_df_v[cms_df_v["Measure ID"] != "PSI_15_ACC_LAC"]
cms_df_w
# Out:
#       Facility ID                                     Facility Name  \
# 13          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 14          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 15          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 16          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 17          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53460      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 13               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 14               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 15               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 16               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 17               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53460  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name       Measure ID  \
# 13        HOUSTON      PSI_3_ULCER
# 14        HOUSTON  PSI_4_SURG_COMP
# 15        HOUSTON    PSI_6_IAT_PTX
# 16        HOUSTON   PSI_8_POST_HIP
# 17        HOUSTON    PSI_90_SAFETY
# ...           ...              ...
# 53459     EL PASO    PSI_90_SAFETY
# 53460      TRAVIS      PSI_3_ULCER
# 53461      TRAVIS    PSI_6_IAT_PTX
# 53462      TRAVIS   PSI_8_POST_HIP
# 53463      TRAVIS    PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 13                                        Pressure sores            9998
# 14     Deaths among Patients with Serious Treatable C...             165
# 15               Collapsed lung due to medical treatment           12963
# 16                  Broken hip from a fall after surgery           10786
# 17                                 Serious complications  Not Applicable
# ...                                                  ...             ...
# 53459                              Serious complications  Not Applicable
# 53460                                     Pressure sores              32
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#         Score Lower Estimate Higher Estimate Start Date   End Date
# 13       0.58           0.13            1.03   7/1/2017  6/30/2019
# 14     170.87         134.19          207.56   7/1/2017  6/30/2019
# 15       0.23           0.06            0.39   7/1/2017  6/30/2019
# 16        0.1           0.03            0.17   7/1/2017  6/30/2019
# 17       0.93            0.7            1.17   7/1/2017  6/30/2019
# ...       ...            ...             ...        ...        ...
# 53459       1            0.5            1.49   7/1/2017  6/30/2019
# 53460    0.59              0               2   7/1/2017  6/30/2019
# 53461    0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462    0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463    0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [33143 rows x 15 columns]

# %%
#filter out PSI_3_ULCER measure
cms_df_x = cms_df_w[cms_df_w["Measure ID"] != "PSI_3_ULCER"]
cms_df_x
# Out:
#       Facility ID                                     Facility Name  \
# 14          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 15          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 16          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 17          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 18          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53458      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 14               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 15               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 16               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 17               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 18               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# ...                                 ...           ...   ...       ...
# 53458   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name       Measure ID  \
# 14        HOUSTON  PSI_4_SURG_COMP
# 15        HOUSTON    PSI_6_IAT_PTX
# 16        HOUSTON   PSI_8_POST_HIP
# 17        HOUSTON    PSI_90_SAFETY
# 18        HOUSTON   PSI_9_POST_HEM
# ...           ...              ...
# 53458     EL PASO   PSI_8_POST_HIP
# 53459     EL PASO    PSI_90_SAFETY
# 53461      TRAVIS    PSI_6_IAT_PTX
# 53462      TRAVIS   PSI_8_POST_HIP
# 53463      TRAVIS    PSI_90_SAFETY
#
#                                             Measure Name     Denominator  \
# 14     Deaths among Patients with Serious Treatable C...             165
# 15               Collapsed lung due to medical treatment           12963
# 16                  Broken hip from a fall after surgery           10786
# 17                                 Serious complications  Not Applicable
# 18             Perioperative Hemorrhage or Hematoma Rate            3590
# ...                                                  ...             ...
# 53458               Broken hip from a fall after surgery              71
# 53459                              Serious complications  Not Applicable
# 53461            Collapsed lung due to medical treatment              59
# 53462               Broken hip from a fall after surgery              55
# 53463                              Serious complications  Not Applicable
#
#         Score Lower Estimate Higher Estimate Start Date   End Date
# 14     170.87         134.19          207.56   7/1/2017  6/30/2019
# 15       0.23           0.06            0.39   7/1/2017  6/30/2019
# 16        0.1           0.03            0.17   7/1/2017  6/30/2019
# 17       0.93            0.7            1.17   7/1/2017  6/30/2019
# 18       2.39           1.36            3.42   7/1/2017  6/30/2019
# ...       ...            ...             ...        ...        ...
# 53458    0.11           0.04            0.18   7/1/2017  6/30/2019
# 53459       1            0.5            1.49   7/1/2017  6/30/2019
# 53461    0.25           0.03            0.48   7/1/2017  6/30/2019
# 53462    0.11           0.04            0.18   7/1/2017  6/30/2019
# 53463    0.99            0.5            1.49   7/1/2017  6/30/2019
#
# [30030 rows x 15 columns]

# %%
#filter out PSI_4_SURG_COMP measure
cms_df_y = cms_df_x[cms_df_x["Measure ID"] != "PSI_4_SURG_COMP"]
cms_df_y
# Out:
#       Facility ID                                     Facility Name  \
# 15          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 16          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 17          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 18          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 34          10005                          MARSHALL MEDICAL CENTERS
# ...           ...                                               ...
# 53458      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53461      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address          City State  ZIP Code  \
# 15               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 16               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 17               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 18               1108 ROSS CLARK CIRCLE        DOTHAN    AL     36301
# 34           2505 U S HIGHWAY 431 NORTH          BOAZ    AL     35957
# ...                                 ...           ...   ...       ...
# 53458   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53459   13600 HORIZON STREET, SUITE 100  HORIZON CITY    TX     79928
# 53461  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY  PFLUGERVILLE    TX     78660
#
#       County Name      Measure ID                               Measure Name  \
# 15        HOUSTON   PSI_6_IAT_PTX    Collapsed lung due to medical treatment
# 16        HOUSTON  PSI_8_POST_HIP       Broken hip from a fall after surgery
# 17        HOUSTON   PSI_90_SAFETY                      Serious complications
# 18        HOUSTON  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate
# 34       MARSHALL   PSI_6_IAT_PTX    Collapsed lung due to medical treatment
# ...           ...             ...                                        ...
# 53458     EL PASO  PSI_8_POST_HIP       Broken hip from a fall after surgery
# 53459     EL PASO   PSI_90_SAFETY                      Serious complications
# 53461      TRAVIS   PSI_6_IAT_PTX    Collapsed lung due to medical treatment
# 53462      TRAVIS  PSI_8_POST_HIP       Broken hip from a fall after surgery
# 53463      TRAVIS   PSI_90_SAFETY                      Serious complications
#
#           Denominator Score Lower Estimate Higher Estimate Start Date  \
# 15              12963  0.23           0.06            0.39   7/1/2017
# 16              10786   0.1           0.03            0.17   7/1/2017
# 17     Not Applicable  0.93            0.7            1.17   7/1/2017
# 18               3590  2.39           1.36            3.42   7/1/2017
# 34               5785  0.21           0.01            0.42   7/1/2017
# ...               ...   ...            ...             ...        ...
# 53458              71  0.11           0.04            0.18   7/1/2017
# 53459  Not Applicable     1            0.5            1.49   7/1/2017
# 53461              59  0.25           0.03            0.48   7/1/2017
# 53462              55  0.11           0.04            0.18   7/1/2017
# 53463  Not Applicable  0.99            0.5            1.49   7/1/2017
#
#         End Date
# 15     6/30/2019
# 16     6/30/2019
# 17     6/30/2019
# 18     6/30/2019
# 34     6/30/2019
# ...          ...
# 53458  6/30/2019
# 53459  6/30/2019
# 53461  6/30/2019
# 53462  6/30/2019
# 53463  6/30/2019
#
# [28322 rows x 15 columns]

# %%
#filter out PSI_6_IAT_PTX measure
cms_df_z = cms_df_y[cms_df_y["Measure ID"] != "PSI_6_IAT_PTX"]
cms_df_z
# Out:
#       Facility ID                                     Facility Name  \
# 16          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 17          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 18          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 35          10005                          MARSHALL MEDICAL CENTERS
# 36          10005                          MARSHALL MEDICAL CENTERS
# ...           ...                                               ...
# 53455      670122          HOUSTON METHODIST THE WOODLANDS HOSPITAL
# 53458      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53462      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address           City State  ZIP Code  \
# 16               1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301
# 17               1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301
# 18               1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301
# 35           2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957
# 36           2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957
# ...                                 ...            ...   ...       ...
# 53455         17201 INTERSTATE 45 SOUTH  THE WOODLANDS    TX     77385
# 53458   13600 HORIZON STREET, SUITE 100   HORIZON CITY    TX     79928
# 53459   13600 HORIZON STREET, SUITE 100   HORIZON CITY    TX     79928
# 53462  2600 EAST  PFLUGERVILLE  PARKWAY   PFLUGERVILLE    TX     78660
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY   PFLUGERVILLE    TX     78660
#
#       County Name      Measure ID                               Measure Name  \
# 16        HOUSTON  PSI_8_POST_HIP       Broken hip from a fall after surgery
# 17        HOUSTON   PSI_90_SAFETY                      Serious complications
# 18        HOUSTON  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate
# 35       MARSHALL  PSI_8_POST_HIP       Broken hip from a fall after surgery
# 36       MARSHALL   PSI_90_SAFETY                      Serious complications
# ...           ...             ...                                        ...
# 53455  MONTGOMERY  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate
# 53458     EL PASO  PSI_8_POST_HIP       Broken hip from a fall after surgery
# 53459     EL PASO   PSI_90_SAFETY                      Serious complications
# 53462      TRAVIS  PSI_8_POST_HIP       Broken hip from a fall after surgery
# 53463      TRAVIS   PSI_90_SAFETY                      Serious complications
#
#           Denominator Score Lower Estimate Higher Estimate Start Date  \
# 16              10786   0.1           0.03            0.17   7/1/2017
# 17     Not Applicable  0.93            0.7            1.17   7/1/2017
# 18               3590  2.39           1.36            3.42   7/1/2017
# 35               5087   0.1           0.03            0.17   7/1/2017
# 36     Not Applicable     1           0.66            1.33   7/1/2017
# ...               ...   ...            ...             ...        ...
# 53455            1253  2.72           1.43            4.02   7/1/2017
# 53458              71  0.11           0.04            0.18   7/1/2017
# 53459  Not Applicable     1            0.5            1.49   7/1/2017
# 53462              55  0.11           0.04            0.18   7/1/2017
# 53463  Not Applicable  0.99            0.5            1.49   7/1/2017
#
#         End Date
# 16     6/30/2019
# 17     6/30/2019
# 18     6/30/2019
# 35     6/30/2019
# 36     6/30/2019
# ...          ...
# 53455  6/30/2019
# 53458  6/30/2019
# 53459  6/30/2019
# 53462  6/30/2019
# 53463  6/30/2019
#
# [25187 rows x 15 columns]

# %%
#filter out PSI_8_POST_HIP measure
cms_df_d = cms_df_z[cms_df_z["Measure ID"] != "PSI_8_POST_HIP"]
cms_df_d
# Out:
#       Facility ID                                     Facility Name  \
# 17          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 18          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 36          10005                          MARSHALL MEDICAL CENTERS
# 37          10005                          MARSHALL MEDICAL CENTERS
# 55          10006                      NORTH ALABAMA MEDICAL CENTER
# ...           ...                                               ...
# 53442      670121                     SAINT CAMILLUS MEDICAL CENTER
# 53454      670122          HOUSTON METHODIST THE WOODLANDS HOSPITAL
# 53455      670122          HOUSTON METHODIST THE WOODLANDS HOSPITAL
# 53459      670124   THE HOSPITALS OF PROVIDENCE HORIZON CITY CAMPUS
# 53463      670128  BAYLOR SCOTT & WHITE MEDICAL CENTER PFLUGERVILLE
#
#                                 Address           City State  ZIP Code  \
# 17               1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301
# 18               1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301
# 36           2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957
# 37           2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957
# 55                  1701 VETERANS DRIVE       FLORENCE    AL     35630
# ...                                 ...            ...   ...       ...
# 53442      1612 HURST TOWN CENTER DRIVE          HURST    TX     76054
# 53454         17201 INTERSTATE 45 SOUTH  THE WOODLANDS    TX     77385
# 53455         17201 INTERSTATE 45 SOUTH  THE WOODLANDS    TX     77385
# 53459   13600 HORIZON STREET, SUITE 100   HORIZON CITY    TX     79928
# 53463  2600 EAST  PFLUGERVILLE  PARKWAY   PFLUGERVILLE    TX     78660
#
#       County Name      Measure ID                               Measure Name  \
# 17        HOUSTON   PSI_90_SAFETY                      Serious complications
# 18        HOUSTON  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate
# 36       MARSHALL   PSI_90_SAFETY                      Serious complications
# 37       MARSHALL  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate
# 55     LAUDERDALE   PSI_90_SAFETY                      Serious complications
# ...           ...             ...                                        ...
# 53442     TARRANT   PSI_90_SAFETY                      Serious complications
# 53454  MONTGOMERY   PSI_90_SAFETY                      Serious complications
# 53455  MONTGOMERY  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate
# 53459     EL PASO   PSI_90_SAFETY                      Serious complications
# 53463      TRAVIS   PSI_90_SAFETY                      Serious complications
#
#           Denominator Score Lower Estimate Higher Estimate Start Date  \
# 17     Not Applicable  0.93            0.7            1.17   7/1/2017
# 18               3590  2.39           1.36            3.42   7/1/2017
# 36     Not Applicable     1           0.66            1.33   7/1/2017
# 37               1040  2.19            0.9            3.49   7/1/2017
# 55     Not Applicable  1.07            0.8            1.35   7/1/2017
# ...               ...   ...            ...             ...        ...
# 53442  Not Applicable  0.99            0.5            1.49   7/1/2017
# 53454  Not Applicable  0.82           0.48            1.15   7/1/2017
# 53455            1253  2.72           1.43            4.02   7/1/2017
# 53459  Not Applicable     1            0.5            1.49   7/1/2017
# 53463  Not Applicable  0.99            0.5            1.49   7/1/2017
#
#         End Date
# 17     6/30/2019
# 18     6/30/2019
# 36     6/30/2019
# 37     6/30/2019
# 55     6/30/2019
# ...          ...
# 53442  6/30/2019
# 53454  6/30/2019
# 53455  6/30/2019
# 53459  6/30/2019
# 53463  6/30/2019
#
# [22056 rows x 15 columns]

# %%
#filter out PSI_90_SAFETY measure
cms_df_e = cms_df_d[cms_df_d["Measure ID"] != "PSI_90_SAFETY"]
cms_df_e
# Out:
#       Facility ID                                     Facility Name  \
# 18          10001                  SOUTHEAST ALABAMA MEDICAL CENTER
# 37          10005                          MARSHALL MEDICAL CENTERS
# 56          10006                      NORTH ALABAMA MEDICAL CENTER
# 73          10007                          MIZELL MEMORIAL HOSPITAL
# 102         10011                                ST. VINCENT'S EAST
# ...           ...                                               ...
# 53407      670110                             TEXAS HEALTH HOSPITAL
# 53417      670112                         LEGENT ORTHOPEDIC + SPINE
# 53428      670116                                WISE HEALTH SYSTEM
# 53441      670120  THE HOSPITALS OF PROVIDENCE TRANSMOUNTAIN CAMPUS
# 53455      670122          HOUSTON METHODIST THE WOODLANDS HOSPITAL
#
#                           Address           City State  ZIP Code County Name  \
# 18         1108 ROSS CLARK CIRCLE         DOTHAN    AL     36301     HOUSTON
# 37     2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957    MARSHALL
# 56            1701 VETERANS DRIVE       FLORENCE    AL     35630  LAUDERDALE
# 73                  702 N MAIN ST            OPP    AL     36467   COVINGTON
# 102    50 MEDICAL PARK EAST DRIVE     BIRMINGHAM    AL     35235   JEFFERSON
# ...                           ...            ...   ...       ...         ...
# 53407   1401 E TRINITY MILLS ROAD     CARROLLTON    TX     75006      DALLAS
# 53417   5330 NORTH LOOP 1604 WEST    SAN ANTONIO    TX     78249       BEXAR
# 53428  3200 NORTH TARRANT PARKWAY     FORT WORTH    TX     76177     TARRANT
# 53441       2000 TRANSMOUNTAIN RD        EL PASO    TX     79911     EL PASO
# 53455   17201 INTERSTATE 45 SOUTH  THE WOODLANDS    TX     77385  MONTGOMERY
#
#            Measure ID                               Measure Name Denominator  \
# 18     PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate        3590
# 37     PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate        1040
# 56     PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate        2505
# 73     PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate          96
# 102    PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate        1506
# ...               ...                                        ...         ...
# 53407  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate         104
# 53417  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate         394
# 53428  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate         161
# 53441  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate         423
# 53455  PSI_9_POST_HEM  Perioperative Hemorrhage or Hematoma Rate        1253
#
#       Score Lower Estimate Higher Estimate Start Date   End Date
# 18     2.39           1.36            3.42   7/1/2017  6/30/2019
# 37     2.19            0.9            3.49   7/1/2017  6/30/2019
# 56     2.91           1.77            4.04   7/1/2017  6/30/2019
# 73     2.46           1.03            3.89   7/1/2017  6/30/2019
# 102    2.43           1.21            3.65   7/1/2017  6/30/2019
# ...     ...            ...             ...        ...        ...
# 53407  2.64           1.22            4.07   7/1/2017  6/30/2019
# 53417  2.68           1.25            4.11   7/1/2017  6/30/2019
# 53428  2.44           1.02            3.86   7/1/2017  6/30/2019
# 53441  2.53           1.14            3.92   7/1/2017  6/30/2019
# 53455  2.72           1.43            4.02   7/1/2017  6/30/2019
#
# [18908 rows x 15 columns]

# %%
#filter out PSI_9_POST_HEM measure
cms_df_f = cms_df_e[cms_df_e["Measure ID"] != "PSI_9_POST_HEM"]
cms_df_f
# Out:
#       Facility ID                                      Facility Name  \
# 2381        50704                         MISSION COMMUNITY HOSPITAL
# 2396       330185  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 2398        50625                        CEDARS-SINAI MEDICAL CENTER
# 2399       140034           SSM HEALTH ST MARY'S HOSPITAL -CENTRALIA
# 2415        50739                  CENTINELA HOSPITAL MEDICAL CENTER
# ...           ...                                                ...
# 38024      340143                      CATAWBA VALLEY MEDICAL CENTER
# 38025      520076  BEAVER DAM COMMUNITY HOSPITAL DBA MARSHFIELD M...
# 38026       50002                                   ST ROSE HOSPITAL
# 38027      170074                           GEARY COMMUNITY HOSPITAL
# 38028      110002                      UPSON REGIONAL MEDICAL CENTER
#
#                          Address            City State  ZIP Code  County Name  \
# 2381           14850 ROSCOE BLVD   PANORAMA CITY    CA     91402  LOS ANGELES
# 2396       75 NORTH COUNTRY ROAD  PORT JEFFERSON    NY     11777      SUFFOLK
# 2398           8700 BEVERLY BLVD     LOS ANGELES    CA     90048  LOS ANGELES
# 2399   400 NORTH PLEASANT AVENUE       CENTRALIA    IL     62801       MARION
# 2415       555 EAST HARDY STREET       INGLEWOOD    CA     90301  LOS ANGELES
# ...                          ...             ...   ...       ...          ...
# 38024    810 FAIRGROVE CHURCH RD         HICKORY    NC     28602      CATAWBA
# 38025       707 S UNIVERSITY AVE      BEAVER DAM    WI     53916        DODGE
# 38026         27200 CALAROGA AVE         HAYWARD    CA     94545      ALAMEDA
# 38027        1102 ST MARY'S ROAD   JUNCTION CITY    KS     66441        GEARY
# 38028        801 W GORDON STREET       THOMASTON    GA     30286        UPSON
#
#          Measure ID                           Measure Name Denominator Score  \
# 2381   MORT_30_COPD           Death rate for COPD patients         207   5.1
# 2396   MORT_30_COPD           Death rate for COPD patients         507   5.1
# 2398   MORT_30_COPD           Death rate for COPD patients         504   5.2
# 2399   MORT_30_COPD           Death rate for COPD patients         531   5.2
# 2415     MORT_30_HF  Death rate for heart failure patients         568   5.3
# ...             ...                                    ...         ...   ...
# 38024    MORT_30_PN      Death rate for pneumonia patients         544  22.8
# 38025    MORT_30_PN      Death rate for pneumonia patients         140  22.8
# 38026    MORT_30_PN      Death rate for pneumonia patients         382    23
# 38027    MORT_30_PN      Death rate for pneumonia patients         125  25.6
# 38028    MORT_30_PN      Death rate for pneumonia patients         184  27.9
#
#       Lower Estimate Higher Estimate Start Date   End Date
# 2381             3.6             6.9   7/1/2016  6/30/2019
# 2396             3.9             6.6   7/1/2016  6/30/2019
# 2398               4             6.6   7/1/2016  6/30/2019
# 2399             3.9             6.8   7/1/2016  6/30/2019
# 2415             4.2             6.7   7/1/2016  6/30/2019
# ...              ...             ...        ...        ...
# 38024           19.8            26.2   7/1/2016  6/30/2019
# 38025           18.1            28.1   7/1/2016  6/30/2019
# 38026           19.7            26.7   7/1/2016  6/30/2019
# 38027           20.2            31.8   7/1/2016  6/30/2019
# 38028           22.4            34.3   7/1/2016  6/30/2019
#
# [15989 rows x 15 columns]

# %%
#filter out mort_30_stk measure
cms_df_g = cms_df_f[cms_df_f["Measure ID"] != "MORT_30_STK"]
cms_df_g
# Out:
#       Facility ID                                      Facility Name  \
# 2381        50704                         MISSION COMMUNITY HOSPITAL
# 2396       330185  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 2398        50625                        CEDARS-SINAI MEDICAL CENTER
# 2399       140034           SSM HEALTH ST MARY'S HOSPITAL -CENTRALIA
# 2415        50739                  CENTINELA HOSPITAL MEDICAL CENTER
# ...           ...                                                ...
# 38024      340143                      CATAWBA VALLEY MEDICAL CENTER
# 38025      520076  BEAVER DAM COMMUNITY HOSPITAL DBA MARSHFIELD M...
# 38026       50002                                   ST ROSE HOSPITAL
# 38027      170074                           GEARY COMMUNITY HOSPITAL
# 38028      110002                      UPSON REGIONAL MEDICAL CENTER
#
#                          Address            City State  ZIP Code  County Name  \
# 2381           14850 ROSCOE BLVD   PANORAMA CITY    CA     91402  LOS ANGELES
# 2396       75 NORTH COUNTRY ROAD  PORT JEFFERSON    NY     11777      SUFFOLK
# 2398           8700 BEVERLY BLVD     LOS ANGELES    CA     90048  LOS ANGELES
# 2399   400 NORTH PLEASANT AVENUE       CENTRALIA    IL     62801       MARION
# 2415       555 EAST HARDY STREET       INGLEWOOD    CA     90301  LOS ANGELES
# ...                          ...             ...   ...       ...          ...
# 38024    810 FAIRGROVE CHURCH RD         HICKORY    NC     28602      CATAWBA
# 38025       707 S UNIVERSITY AVE      BEAVER DAM    WI     53916        DODGE
# 38026         27200 CALAROGA AVE         HAYWARD    CA     94545      ALAMEDA
# 38027        1102 ST MARY'S ROAD   JUNCTION CITY    KS     66441        GEARY
# 38028        801 W GORDON STREET       THOMASTON    GA     30286        UPSON
#
#          Measure ID                           Measure Name Denominator Score  \
# 2381   MORT_30_COPD           Death rate for COPD patients         207   5.1
# 2396   MORT_30_COPD           Death rate for COPD patients         507   5.1
# 2398   MORT_30_COPD           Death rate for COPD patients         504   5.2
# 2399   MORT_30_COPD           Death rate for COPD patients         531   5.2
# 2415     MORT_30_HF  Death rate for heart failure patients         568   5.3
# ...             ...                                    ...         ...   ...
# 38024    MORT_30_PN      Death rate for pneumonia patients         544  22.8
# 38025    MORT_30_PN      Death rate for pneumonia patients         140  22.8
# 38026    MORT_30_PN      Death rate for pneumonia patients         382    23
# 38027    MORT_30_PN      Death rate for pneumonia patients         125  25.6
# 38028    MORT_30_PN      Death rate for pneumonia patients         184  27.9
#
#       Lower Estimate Higher Estimate Start Date   End Date
# 2381             3.6             6.9   7/1/2016  6/30/2019
# 2396             3.9             6.6   7/1/2016  6/30/2019
# 2398               4             6.6   7/1/2016  6/30/2019
# 2399             3.9             6.8   7/1/2016  6/30/2019
# 2415             4.2             6.7   7/1/2016  6/30/2019
# ...              ...             ...        ...        ...
# 38024           19.8            26.2   7/1/2016  6/30/2019
# 38025           18.1            28.1   7/1/2016  6/30/2019
# 38026           19.7            26.7   7/1/2016  6/30/2019
# 38027           20.2            31.8   7/1/2016  6/30/2019
# 38028           22.4            34.3   7/1/2016  6/30/2019
#
# [13555 rows x 15 columns]

# %%
#reset index
cms_df_mort = cms_df_g.reset_index(drop=True)
cms_df_mort
# Out:
#       Facility ID                                      Facility Name  \
# 0           50704                         MISSION COMMUNITY HOSPITAL
# 1          330185  JOHN T MATHER MEMORIAL HOSPITAL  OF PORT JEFFE...
# 2           50625                        CEDARS-SINAI MEDICAL CENTER
# 3          140034           SSM HEALTH ST MARY'S HOSPITAL -CENTRALIA
# 4           50739                  CENTINELA HOSPITAL MEDICAL CENTER
# ...           ...                                                ...
# 13550      340143                      CATAWBA VALLEY MEDICAL CENTER
# 13551      520076  BEAVER DAM COMMUNITY HOSPITAL DBA MARSHFIELD M...
# 13552       50002                                   ST ROSE HOSPITAL
# 13553      170074                           GEARY COMMUNITY HOSPITAL
# 13554      110002                      UPSON REGIONAL MEDICAL CENTER
#
#                          Address            City State  ZIP Code  County Name  \
# 0              14850 ROSCOE BLVD   PANORAMA CITY    CA     91402  LOS ANGELES
# 1          75 NORTH COUNTRY ROAD  PORT JEFFERSON    NY     11777      SUFFOLK
# 2              8700 BEVERLY BLVD     LOS ANGELES    CA     90048  LOS ANGELES
# 3      400 NORTH PLEASANT AVENUE       CENTRALIA    IL     62801       MARION
# 4          555 EAST HARDY STREET       INGLEWOOD    CA     90301  LOS ANGELES
# ...                          ...             ...   ...       ...          ...
# 13550    810 FAIRGROVE CHURCH RD         HICKORY    NC     28602      CATAWBA
# 13551       707 S UNIVERSITY AVE      BEAVER DAM    WI     53916        DODGE
# 13552         27200 CALAROGA AVE         HAYWARD    CA     94545      ALAMEDA
# 13553        1102 ST MARY'S ROAD   JUNCTION CITY    KS     66441        GEARY
# 13554        801 W GORDON STREET       THOMASTON    GA     30286        UPSON
#
#          Measure ID                           Measure Name Denominator Score  \
# 0      MORT_30_COPD           Death rate for COPD patients         207   5.1
# 1      MORT_30_COPD           Death rate for COPD patients         507   5.1
# 2      MORT_30_COPD           Death rate for COPD patients         504   5.2
# 3      MORT_30_COPD           Death rate for COPD patients         531   5.2
# 4        MORT_30_HF  Death rate for heart failure patients         568   5.3
# ...             ...                                    ...         ...   ...
# 13550    MORT_30_PN      Death rate for pneumonia patients         544  22.8
# 13551    MORT_30_PN      Death rate for pneumonia patients         140  22.8
# 13552    MORT_30_PN      Death rate for pneumonia patients         382    23
# 13553    MORT_30_PN      Death rate for pneumonia patients         125  25.6
# 13554    MORT_30_PN      Death rate for pneumonia patients         184  27.9
#
#       Lower Estimate Higher Estimate Start Date   End Date
# 0                3.6             6.9   7/1/2016  6/30/2019
# 1                3.9             6.6   7/1/2016  6/30/2019
# 2                  4             6.6   7/1/2016  6/30/2019
# 3                3.9             6.8   7/1/2016  6/30/2019
# 4                4.2             6.7   7/1/2016  6/30/2019
# ...              ...             ...        ...        ...
# 13550           19.8            26.2   7/1/2016  6/30/2019
# 13551           18.1            28.1   7/1/2016  6/30/2019
# 13552           19.7            26.7   7/1/2016  6/30/2019
# 13553           20.2            31.8   7/1/2016  6/30/2019
# 13554           22.4            34.3   7/1/2016  6/30/2019
#
# [13555 rows x 15 columns]

# %%
#Added clean csv to resources folder
cms_df_mort.to_csv("Resources/four_mort_measures.csv", index = False, header=True)
